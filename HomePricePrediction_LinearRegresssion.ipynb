# %% [markdown]
# <a href="https://colab.research.google.com/github/21p31a04g5/Machine_Learning/blob/main/HomePricePrediction_LinearRegresssion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(x=df.area, y=df.price,marker='+',color='red')
plt.xlabel('area')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
new_df=df.drop('price',axis=1)
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price=df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(new_df,price)
# Out:
# LinearRegression()

# %%
reg.predict([[5000]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
#y = m*x + c
y=135.78767123*5000+180616.43835616432
y
# Out:
# 859554.7945061643

# %%
areas=pd.read_csv('areas.csv')
areas.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
predictions = reg.predict(areas)
predictions
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
areas['prices']=predictions
areas.head()
# Out:
#    area         prices
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  2300  492928.082192
# 3  3540  661304.794521
# 4  4120  740061.643836

# %%
areas.to_csv('predictions.csv')

# %%
#Another Example

# %%
df1=pd.read_csv('canada_per_capita_income.csv')
df1.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.xlabel('year')
plt.ylabel('per capita income')
plt.scatter(x= df1['year'], y=df1['per capita income (US$)'],marker="+",color='red')

# %%
a=df1.drop('per capita income (US$)',axis=1)
a.head(3)
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972

# %%
income=df1['per capita income (US$)']
income.head(3)
# Out:
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# Name: per capita income (US$), dtype: float64

# %%
reg1=LinearRegression()
reg1.fit(a,income)
# Out:
# LinearRegression()

# %%
predictions1 = reg1.predict(income.values.reshape(-1, 1))
predictions1
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([ 1183989.77453723,  1489692.4743259 ,  1889739.65928155,
#         2348119.24830361,  2987736.81563018,  3337042.34895011,
#         4218518.45705049,  4249995.80366433,  4372476.79700754,
#         4666536.86832091,  5290416.99923891,  6183852.40333416,
#         6337157.98074608,  6997526.01173901,  7307199.73683711,
#         7496609.32929052,  7880963.83732022,  9116963.38458296,
#        10861277.40492859, 11976757.60259556, 12318041.90143318,
#        12672148.16369306, 11964626.89386277, 11520158.39661866,
#        11420936.0673256 , 11929196.8890102 , 12203012.40879697,
#        12709147.46366041, 12139092.34332652, 12933053.72878193,
#        14098172.43872756, 13778397.20582866, 14300975.01415631,
#        17206609.74572602, 19675204.42043325, 22557358.64571728,
# ...

# %%
reg1.predict([[2024]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([44602.55439531])

# %%
#Another example

# %%
df2=pd.read_csv('homeprices (1).csv')
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df2.bedrooms
# Out:
# 0    3.0
# 1    4.0
# 2    NaN
# 3    3.0
# 4    5.0
# 5    6.0
# Name: bedrooms, dtype: float64

# %%
import math
medianofbedrooms=math.floor(df2.bedrooms.median())
medianofbedrooms
# Out:
# 4

# %%
df2=df2.fillna(medianofbedrooms)
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg2 = LinearRegression()
reg2.fit(df2[['area','bedrooms','price']],df2['age'])
# Out:
# LinearRegression()

# %%
reg2.predict([[5000,6,900000]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10.63341281])

# %%
reg2.coef_
# Out:
# array([ 1.09207423e-02, -6.53549070e+00, -4.44080646e-05])

# %%
reg2.intercept_
# Out:
# 35.20990351192352

# %%
#y=mX+c
ye=1.09207423e-02*5000 + -6.53549070e+00*6 + -4.44080646e-05*900000 + 35.20990351192352
ye
# Out:
# 10.633412671923516
